# %%
# import the packages
from __future__ import print_function
import tensorflow as tf
from tensorflow.contrib import rnn
import numpy as np
import pandas as pd
import os
import datetime
import random

# %%
# Training Parameters
learning_rate = 0.005
training_steps = 2000
batch_size = 500
display_step = 100

# Network Parameters
num_input = 3 # the stock price, the sector, and the volume
timesteps = 240 # timesteps
num_hidden = 50 # hidden layer num of features
num_classes = 1 # above or below the median
dropout = 0.1
threshold = tf.constant(0.5)

# %%
# tf Graph input
X = tf.placeholder("float", [None, timesteps, num_input])
Y = tf.placeholder("float", [None, num_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([num_hidden, num_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# %%
def RNN(x, weights, biases):
    # Current data input shape: (batch_size, timesteps, num_input)
    # Required shape: 'timesteps' tensors list of shape (batch_size, num_input)

    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, num_input)
    x = tf.unstack(x, timesteps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(num_hidden, forget_bias=0.8)

    # Apply the Dropout
    lstm_cell = tf.nn.rnn_cell.DropoutWrapper(lstm_cell, input_keep_prob=1.0, output_keep_prob=1.0 - dropout,
                                              state_keep_prob=1.0 - dropout)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

logits = RNN(X, weights, biases)
prediction = tf.nn.sigmoid(logits) # for prediction, [0, 1]

# %%
# Define loss and optimizer
x_entropy = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=Y)
loss_op = tf.reduce_mean(x_entropy)
optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluate model (with test logits, for dropout to be disabled)
delta = tf.abs((Y - prediction))
correct_pred = tf.cast(tf.less(delta, threshold), tf.int32)
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# the tool to save the results
saver = tf.train.Saver()

label = list(range(timesteps * num_input)) + ['target'] + ['ticker'] + ['target_date'] + ['sector']

# %%
for i in range(13):
    # read the data
    training_name = os.path.join(os.getcwd(), 'data\\Set_' + str(i) + '_Train.csv')
    testing_name = os.path.join(os.getcwd(), 'data\\Set_' + str(i) + '_Test.csv')
    train_data = pd.read_csv(training_name, index_col=0)
    test_data = pd.read_csv(testing_name, index_col=0)

    train_data.columns = label
    test_data.columns = label

    training_label = train_data.iloc[:, timesteps * num_input]
    training_data = train_data.iloc[:, :timesteps * num_input]
    testing_label = test_data.iloc[:, timesteps * num_input]
    testing_data = test_data.iloc[:, :timesteps * num_input]

    # Start training
    with tf.Session() as sess:
        # print the training info
        print("-------------------------------------------------------------------------------------------------------")
        print("Training the model for Training Set " + str(i) + " from " +
              datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S') + "...")
        print("-------------------------------------------------------------------------------------------------------")

        # Run the initializer
        sess.run(init)

        # Restore model weights from previously saved model
        if i != 0:
            # log_path = os.path.join(os.getcwd(), 'Logs\\model_for_period_' + str(i - 1))
            # save_path = saver.save(sess, log_path)
            load_path = saver.restore(sess, log_path)
            print("Model restored from file: %s" % save_path)

        for step in range(training_steps):
            # if (step + 1) * batch_size > len(train_data):
            #     break
            # batch = train_data.iloc[step * batch_size : (step + 1) * batch_size, :]

            batch_ind = random.sample(range(len(train_data)), batch_size)
            batch = train_data.iloc[batch_ind, :]

            # query the data from the data set
            batch_x = np.array(batch.iloc[:, :timesteps * num_input])
            batch_x = batch_x.reshape((batch_size, timesteps, num_input), order = 'F')
            batch_y = np.array(batch.iloc[:, timesteps * num_input])
            batch_y = batch_y.reshape((batch_size, num_classes))

            # Run optimization op (backprop)
            sess.run(train_op, feed_dict={X: batch_x, Y: batch_y})
            if step % display_step == 0:
                # Calculate batch loss and accuracy
                loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x, Y: batch_y})
                print("Step " + str(step) + ",bibatch Loss = " + \
                      "{:.4f}".format(loss) + ", Training Accuracy = " + \
                      "{:.3f}".format(acc))

        testing_data = np.array(testing_data).reshape((len(testing_data), timesteps, num_input), order = 'F')
        testing_label = np.array(testing_label).reshape((len(testing_label), num_classes))
        training_data = np.array(training_data).reshape((len(training_data), timesteps, num_input), order = 'F')
        training_label = np.array(training_label).reshape((len(training_label), num_classes))
        print("Overall Training Accuracy:", sess.run(accuracy, feed_dict={X: training_data, Y: training_label}))
        print("Testing Accuracy:", sess.run(accuracy, feed_dict={X: testing_data, Y: testing_label}))

        log_path = os.path.join(os.getcwd(), 'Logs\\model_for_period_' + str(i))
        save_path = saver.save(sess, log_path)
        print("Model saved in file: %s" % save_path)

        pred = sess.run(prediction, feed_dict={X: testing_data, Y: testing_label})
        pred = pred.reshape((1, len(pred))).tolist()[0]
        output_data = pd.DataFrame({'y_prob': pred, 'y_true': test_data['target'], 'Ticker': test_data['ticker'],
                                    'Date': test_data['target_date'], 'Sector': test_data['sector'], })
        output_path = os.path.join(os.getcwd(), 'Pred\\prediction_period_' + str(i) + '.csv')
        output_data.to_csv(output_path)
        print('Prediction for period ' + str(i) + ' successfully shaved.')
# Out:
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 0 from 2018-12-30 23:14:23...
# -------------------------------------------------------------------------------------------------------
# Step 0,bibatch Loss = 0.7968, Training Accuracy = 0.490
# Step 100,bibatch Loss = 0.6956, Training Accuracy = 0.486
# Step 200,bibatch Loss = 0.6922, Training Accuracy = 0.520
# Step 300,bibatch Loss = 0.6893, Training Accuracy = 0.504
# Step 400,bibatch Loss = 0.6892, Training Accuracy = 0.536
# Step 500,bibatch Loss = 0.6923, Training Accuracy = 0.508
# Step 600,bibatch Loss = 0.6885, Training Accuracy = 0.540
# Step 700,bibatch Loss = 0.6921, Training Accuracy = 0.508
# Step 800,bibatch Loss = 0.6914, Training Accuracy = 0.514
# Step 900,bibatch Loss = 0.6862, Training Accuracy = 0.526
# Step 1000,bibatch Loss = 0.6948, Training Accuracy = 0.470
# Step 1100,bibatch Loss = 0.6920, Training Accuracy = 0.480
# Step 1200,bibatch Loss = 0.6904, Training Accuracy = 0.516
# Step 1300,bibatch Loss = 0.6886, Training Accuracy = 0.544
# Step 1400,bibatch Loss = 0.6936, Training Accuracy = 0.484
# Step 1500,bibatch Loss = 0.6926, Training Accuracy = 0.524
# Step 1600,bibatch Loss = 0.6915, Training Accuracy = 0.512
# Step 1700,bibatch Loss = 0.6901, Training Accuracy = 0.538
# Step 1800,bibatch Loss = 0.6885, Training Accuracy = 0.532
# Step 1900,bibatch Loss = 0.6935, Training Accuracy = 0.506
# Overall Training Accuracy: 0.5133142
# Testing Accuracy: 0.50952405
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_0
# Prediction for period 0 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 1 from 2018-12-30 23:45:33...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_0
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_0
# Step 0,bibatch Loss = 0.6867, Training Accuracy = 0.566
# Step 100,bibatch Loss = 0.6934, Training Accuracy = 0.512
# Step 200,bibatch Loss = 0.6882, Training Accuracy = 0.534
# Step 300,bibatch Loss = 0.6900, Training Accuracy = 0.522
# Step 400,bibatch Loss = 0.6902, Training Accuracy = 0.518
# Step 500,bibatch Loss = 0.6935, Training Accuracy = 0.504
# Step 600,bibatch Loss = 0.6914, Training Accuracy = 0.522
# Step 700,bibatch Loss = 0.6888, Training Accuracy = 0.550
# Step 800,bibatch Loss = 0.6905, Training Accuracy = 0.534
# Step 900,bibatch Loss = 0.6865, Training Accuracy = 0.554
# Step 1000,bibatch Loss = 0.6902, Training Accuracy = 0.554
# Step 1100,bibatch Loss = 0.6881, Training Accuracy = 0.528
# Step 1200,bibatch Loss = 0.6917, Training Accuracy = 0.520
# Step 1300,bibatch Loss = 0.6906, Training Accuracy = 0.512
# Step 1400,bibatch Loss = 0.6891, Training Accuracy = 0.524
# Step 1500,bibatch Loss = 0.6807, Training Accuracy = 0.536
# Step 1600,bibatch Loss = 0.6902, Training Accuracy = 0.540
# Step 1700,bibatch Loss = 0.6830, Training Accuracy = 0.522
# Step 1800,bibatch Loss = 0.6862, Training Accuracy = 0.538
# Step 1900,bibatch Loss = 0.6823, Training Accuracy = 0.536
# Overall Training Accuracy: 0.5186668
# Testing Accuracy: 0.5033852
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_1
# Prediction for period 1 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 2 from 2018-12-31 00:14:51...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_1
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_1
# Step 0,bibatch Loss = 0.6937, Training Accuracy = 0.472
# Step 100,bibatch Loss = 0.6884, Training Accuracy = 0.514
# Step 200,bibatch Loss = 0.6897, Training Accuracy = 0.536
# Step 300,bibatch Loss = 0.6925, Training Accuracy = 0.512
# Step 400,bibatch Loss = 0.6905, Training Accuracy = 0.488
# Step 500,bibatch Loss = 0.6890, Training Accuracy = 0.530
# Step 600,bibatch Loss = 0.6920, Training Accuracy = 0.508
# Step 700,bibatch Loss = 0.6891, Training Accuracy = 0.518
# Step 800,bibatch Loss = 0.6922, Training Accuracy = 0.534
# Step 900,bibatch Loss = 0.6807, Training Accuracy = 0.546
# Step 1000,bibatch Loss = 0.6781, Training Accuracy = 0.542
# Step 1100,bibatch Loss = 0.6904, Training Accuracy = 0.516
# Step 1200,bibatch Loss = 0.6857, Training Accuracy = 0.526
# Step 1300,bibatch Loss = 0.6770, Training Accuracy = 0.522
# Step 1400,bibatch Loss = 0.6836, Training Accuracy = 0.534
# Step 1500,bibatch Loss = 0.6930, Training Accuracy = 0.534
# Step 1600,bibatch Loss = 0.6787, Training Accuracy = 0.598
# Step 1700,bibatch Loss = 0.6878, Training Accuracy = 0.502
# Step 1800,bibatch Loss = 0.6828, Training Accuracy = 0.522
# Step 1900,bibatch Loss = 0.6749, Training Accuracy = 0.568
# Overall Training Accuracy: 0.52745676
# Testing Accuracy: 0.5045008
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_2
# Prediction for period 2 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 3 from 2018-12-31 00:45:21...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_2
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_2
# Step 0,bibatch Loss = 0.6853, Training Accuracy = 0.486
# Step 100,bibatch Loss = 0.6906, Training Accuracy = 0.514
# Step 200,bibatch Loss = 0.6853, Training Accuracy = 0.552
# Step 300,bibatch Loss = 0.6875, Training Accuracy = 0.520
# Step 400,bibatch Loss = 0.6920, Training Accuracy = 0.494
# Step 500,bibatch Loss = 0.6862, Training Accuracy = 0.550
# Step 600,bibatch Loss = 0.6810, Training Accuracy = 0.542
# Step 700,bibatch Loss = 0.6930, Training Accuracy = 0.470
# Step 800,bibatch Loss = 0.6761, Training Accuracy = 0.546
# Step 900,bibatch Loss = 0.6934, Training Accuracy = 0.518
# Step 1000,bibatch Loss = 0.6821, Training Accuracy = 0.584
# Step 1100,bibatch Loss = 0.6816, Training Accuracy = 0.532
# Step 1200,bibatch Loss = 0.6732, Training Accuracy = 0.530
# Step 1300,bibatch Loss = 0.6837, Training Accuracy = 0.558
# Step 1400,bibatch Loss = 0.6876, Training Accuracy = 0.496
# Step 1500,bibatch Loss = 0.6779, Training Accuracy = 0.568
# Step 1600,bibatch Loss = 0.6810, Training Accuracy = 0.558
# Step 1700,bibatch Loss = 0.6781, Training Accuracy = 0.544
# Step 1800,bibatch Loss = 0.6698, Training Accuracy = 0.558
# Step 1900,bibatch Loss = 0.6676, Training Accuracy = 0.590
# Overall Training Accuracy: 0.543715
# Testing Accuracy: 0.5025107
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_3
# Prediction for period 3 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 4 from 2018-12-31 01:16:28...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_3
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_3
# Step 0,bibatch Loss = 0.6865, Training Accuracy = 0.512
# Step 100,bibatch Loss = 0.6734, Training Accuracy = 0.562
# Step 200,bibatch Loss = 0.6867, Training Accuracy = 0.534
# Step 300,bibatch Loss = 0.6862, Training Accuracy = 0.522
# Step 400,bibatch Loss = 0.6760, Training Accuracy = 0.558
# Step 500,bibatch Loss = 0.6784, Training Accuracy = 0.528
# Step 600,bibatch Loss = 0.6721, Training Accuracy = 0.536
# Step 700,bibatch Loss = 0.6786, Training Accuracy = 0.538
# Step 800,bibatch Loss = 0.6735, Training Accuracy = 0.570
# Step 900,bibatch Loss = 0.6799, Training Accuracy = 0.556
# Step 1000,bibatch Loss = 0.6688, Training Accuracy = 0.582
# Step 1100,bibatch Loss = 0.6712, Training Accuracy = 0.564
# Step 1200,bibatch Loss = 0.6783, Training Accuracy = 0.536
# Step 1300,bibatch Loss = 0.6499, Training Accuracy = 0.588
# Step 1400,bibatch Loss = 0.6701, Training Accuracy = 0.542
# Step 1500,bibatch Loss = 0.6645, Training Accuracy = 0.596
# Step 1600,bibatch Loss = 0.6758, Training Accuracy = 0.538
# Step 1700,bibatch Loss = 0.6768, Training Accuracy = 0.556
# Step 1800,bibatch Loss = 0.6502, Training Accuracy = 0.568
# Step 1900,bibatch Loss = 0.6754, Training Accuracy = 0.566
# Overall Training Accuracy: 0.5604169
# Testing Accuracy: 0.5063685
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_4
# Prediction for period 4 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 5 from 2018-12-31 01:50:22...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_4
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_4
# Step 0,bibatch Loss = 0.6750, Training Accuracy = 0.552
# Step 100,bibatch Loss = 0.6800, Training Accuracy = 0.586
# Step 200,bibatch Loss = 0.6788, Training Accuracy = 0.528
# Step 300,bibatch Loss = 0.6878, Training Accuracy = 0.510
# Step 400,bibatch Loss = 0.6872, Training Accuracy = 0.538
# Step 500,bibatch Loss = 0.6716, Training Accuracy = 0.580
# Step 600,bibatch Loss = 0.6699, Training Accuracy = 0.568
# Step 700,bibatch Loss = 0.6764, Training Accuracy = 0.560
# Step 800,bibatch Loss = 0.6823, Training Accuracy = 0.514
# Step 900,bibatch Loss = 0.6799, Training Accuracy = 0.536
# Step 1000,bibatch Loss = 0.6750, Training Accuracy = 0.558
# Step 1100,bibatch Loss = 0.6714, Training Accuracy = 0.544
# Step 1200,bibatch Loss = 0.6753, Training Accuracy = 0.558
# Step 1300,bibatch Loss = 0.6747, Training Accuracy = 0.568
# Step 1400,bibatch Loss = 0.6763, Training Accuracy = 0.554
# Step 1500,bibatch Loss = 0.6687, Training Accuracy = 0.534
# Step 1600,bibatch Loss = 0.6703, Training Accuracy = 0.580
# Step 1700,bibatch Loss = 0.6637, Training Accuracy = 0.590
# Step 1800,bibatch Loss = 0.6685, Training Accuracy = 0.574
# Step 1900,bibatch Loss = 0.6354, Training Accuracy = 0.614
# Overall Training Accuracy: 0.55045396
# Testing Accuracy: 0.50311977
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_5
# Prediction for period 5 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 6 from 2018-12-31 02:23:43...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_5
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_5
# Step 0,bibatch Loss = 0.6879, Training Accuracy = 0.520
# Step 100,bibatch Loss = 0.6850, Training Accuracy = 0.516
# Step 200,bibatch Loss = 0.6857, Training Accuracy = 0.534
# Step 300,bibatch Loss = 0.6833, Training Accuracy = 0.528
# Step 400,bibatch Loss = 0.6847, Training Accuracy = 0.532
# Step 500,bibatch Loss = 0.6831, Training Accuracy = 0.554
# Step 600,bibatch Loss = 0.6913, Training Accuracy = 0.498
# Step 700,bibatch Loss = 0.6807, Training Accuracy = 0.588
# Step 800,bibatch Loss = 0.6815, Training Accuracy = 0.524
# Step 900,bibatch Loss = 0.6724, Training Accuracy = 0.584
# Step 1000,bibatch Loss = 0.6858, Training Accuracy = 0.498
# Step 1100,bibatch Loss = 0.6716, Training Accuracy = 0.548
# Step 1200,bibatch Loss = 0.6785, Training Accuracy = 0.578
# Step 1300,bibatch Loss = 0.6771, Training Accuracy = 0.552
# Step 1400,bibatch Loss = 0.6678, Training Accuracy = 0.590
# Step 1500,bibatch Loss = 0.6867, Training Accuracy = 0.514
# Step 1600,bibatch Loss = 0.6733, Training Accuracy = 0.552
# Step 1700,bibatch Loss = 0.6889, Training Accuracy = 0.540
# Step 1800,bibatch Loss = 0.6899, Training Accuracy = 0.490
# Step 1900,bibatch Loss = 0.6792, Training Accuracy = 0.518
# Overall Training Accuracy: 0.54018533
# Testing Accuracy: 0.5040972
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_6
# Prediction for period 6 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 7 from 2018-12-31 03:01:08...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_6
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_6
# Step 0,bibatch Loss = 0.6952, Training Accuracy = 0.554
# Step 100,bibatch Loss = 0.6854, Training Accuracy = 0.528
# Step 200,bibatch Loss = 0.6790, Training Accuracy = 0.540
# Step 300,bibatch Loss = 0.6846, Training Accuracy = 0.566
# Step 400,bibatch Loss = 0.6866, Training Accuracy = 0.550
# Step 500,bibatch Loss = 0.6903, Training Accuracy = 0.534
# Step 600,bibatch Loss = 0.6779, Training Accuracy = 0.570
# Step 700,bibatch Loss = 0.6834, Training Accuracy = 0.542
# Step 800,bibatch Loss = 0.6807, Training Accuracy = 0.558
# Step 900,bibatch Loss = 0.6833, Training Accuracy = 0.552
# Step 1000,bibatch Loss = 0.6837, Training Accuracy = 0.520
# Step 1100,bibatch Loss = 0.6764, Training Accuracy = 0.564
# Step 1200,bibatch Loss = 0.6738, Training Accuracy = 0.546
# Step 1300,bibatch Loss = 0.6801, Training Accuracy = 0.536
# Step 1400,bibatch Loss = 0.6789, Training Accuracy = 0.568
# Step 1500,bibatch Loss = 0.6750, Training Accuracy = 0.578
# Step 1600,bibatch Loss = 0.6678, Training Accuracy = 0.592
# Step 1700,bibatch Loss = 0.6805, Training Accuracy = 0.562
# Step 1800,bibatch Loss = 0.6644, Training Accuracy = 0.572
# Step 1900,bibatch Loss = 0.6795, Training Accuracy = 0.536
# Overall Training Accuracy: 0.5516169
# Testing Accuracy: 0.5014455
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_7
# Prediction for period 7 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 8 from 2018-12-31 03:42:39...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_7
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_7
# Step 0,bibatch Loss = 0.6819, Training Accuracy = 0.536
# Step 100,bibatch Loss = 0.6800, Training Accuracy = 0.562
# Step 200,bibatch Loss = 0.6831, Training Accuracy = 0.556
# Step 300,bibatch Loss = 0.6753, Training Accuracy = 0.606
# Step 400,bibatch Loss = 0.6817, Training Accuracy = 0.548
# Step 500,bibatch Loss = 0.6821, Training Accuracy = 0.576
# Step 600,bibatch Loss = 0.6841, Training Accuracy = 0.544
# Step 700,bibatch Loss = 0.6866, Training Accuracy = 0.542
# Step 800,bibatch Loss = 0.6884, Training Accuracy = 0.514
# Step 900,bibatch Loss = 0.6737, Training Accuracy = 0.596
# Step 1000,bibatch Loss = 0.6724, Training Accuracy = 0.560
# Step 1100,bibatch Loss = 0.6865, Training Accuracy = 0.564
# Step 1200,bibatch Loss = 0.6911, Training Accuracy = 0.496
# Step 1300,bibatch Loss = 0.6858, Training Accuracy = 0.500
# Step 1400,bibatch Loss = 0.6769, Training Accuracy = 0.560
# Step 1500,bibatch Loss = 0.6806, Training Accuracy = 0.524
# Step 1600,bibatch Loss = 0.6819, Training Accuracy = 0.580
# Step 1700,bibatch Loss = 0.6724, Training Accuracy = 0.596
# Step 1800,bibatch Loss = 0.6695, Training Accuracy = 0.578
# Step 1900,bibatch Loss = 0.6718, Training Accuracy = 0.564
# Overall Training Accuracy: 0.5395774
# Testing Accuracy: 0.50348103
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_8
# Prediction for period 8 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 9 from 2018-12-31 04:23:49...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_8
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_8
# Step 0,bibatch Loss = 0.6970, Training Accuracy = 0.504
# Step 100,bibatch Loss = 0.6882, Training Accuracy = 0.524
# Step 200,bibatch Loss = 0.6890, Training Accuracy = 0.504
# Step 300,bibatch Loss = 0.6889, Training Accuracy = 0.520
# Step 400,bibatch Loss = 0.6878, Training Accuracy = 0.546
# Step 500,bibatch Loss = 0.6863, Training Accuracy = 0.542
# Step 600,bibatch Loss = 0.6854, Training Accuracy = 0.526
# Step 700,bibatch Loss = 0.6919, Training Accuracy = 0.534
# Step 800,bibatch Loss = 0.6864, Training Accuracy = 0.536
# Step 900,bibatch Loss = 0.6861, Training Accuracy = 0.542
# Step 1000,bibatch Loss = 0.6886, Training Accuracy = 0.540
# Step 1100,bibatch Loss = 0.6837, Training Accuracy = 0.554
# Step 1200,bibatch Loss = 0.6843, Training Accuracy = 0.562
# Step 1300,bibatch Loss = 0.6812, Training Accuracy = 0.536
# Step 1400,bibatch Loss = 0.6825, Training Accuracy = 0.548
# Step 1500,bibatch Loss = 0.6850, Training Accuracy = 0.542
# Step 1600,bibatch Loss = 0.6799, Training Accuracy = 0.574
# Step 1700,bibatch Loss = 0.6944, Training Accuracy = 0.512
# Step 1800,bibatch Loss = 0.6878, Training Accuracy = 0.570
# Step 1900,bibatch Loss = 0.6785, Training Accuracy = 0.566
# Overall Training Accuracy: 0.5353308
# Testing Accuracy: 0.50562257
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_9
# Prediction for period 9 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 10 from 2018-12-31 05:05:44...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_9
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_9
# Step 0,bibatch Loss = 0.6922, Training Accuracy = 0.528
# Step 100,bibatch Loss = 0.6909, Training Accuracy = 0.528
# Step 200,bibatch Loss = 0.6835, Training Accuracy = 0.554
# Step 300,bibatch Loss = 0.6807, Training Accuracy = 0.582
# Step 400,bibatch Loss = 0.6779, Training Accuracy = 0.566
# Step 500,bibatch Loss = 0.6866, Training Accuracy = 0.536
# Step 600,bibatch Loss = 0.6860, Training Accuracy = 0.522
# Step 700,bibatch Loss = 0.6852, Training Accuracy = 0.530
# Step 800,bibatch Loss = 0.6839, Training Accuracy = 0.516
# Step 900,bibatch Loss = 0.6803, Training Accuracy = 0.554
# Step 1000,bibatch Loss = 0.6789, Training Accuracy = 0.564
# Step 1100,bibatch Loss = 0.6832, Training Accuracy = 0.516
# Step 1200,bibatch Loss = 0.6879, Training Accuracy = 0.496
# Step 1300,bibatch Loss = 0.6818, Training Accuracy = 0.552
# Step 1400,bibatch Loss = 0.6827, Training Accuracy = 0.552
# Step 1500,bibatch Loss = 0.6739, Training Accuracy = 0.558
# Step 1600,bibatch Loss = 0.6781, Training Accuracy = 0.572
# Step 1700,bibatch Loss = 0.6732, Training Accuracy = 0.562
# Step 1800,bibatch Loss = 0.6828, Training Accuracy = 0.546
# Step 1900,bibatch Loss = 0.6820, Training Accuracy = 0.548
# Overall Training Accuracy: 0.544492
# Testing Accuracy: 0.50436836
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_10
# Prediction for period 10 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 11 from 2018-12-31 05:46:43...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_10
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_10
# Step 0,bibatch Loss = 0.6766, Training Accuracy = 0.550
# Step 100,bibatch Loss = 0.6793, Training Accuracy = 0.556
# Step 200,bibatch Loss = 0.6869, Training Accuracy = 0.534
# Step 300,bibatch Loss = 0.6784, Training Accuracy = 0.570
# Step 400,bibatch Loss = 0.6925, Training Accuracy = 0.502
# Step 500,bibatch Loss = 0.6775, Training Accuracy = 0.552
# Step 600,bibatch Loss = 0.6826, Training Accuracy = 0.540
# Step 700,bibatch Loss = 0.6837, Training Accuracy = 0.530
# Step 800,bibatch Loss = 0.6746, Training Accuracy = 0.556
# Step 900,bibatch Loss = 0.6807, Training Accuracy = 0.570
# Step 1000,bibatch Loss = 0.6820, Training Accuracy = 0.524
# Step 1100,bibatch Loss = 0.6794, Training Accuracy = 0.570
# Step 1200,bibatch Loss = 0.6848, Training Accuracy = 0.542
# Step 1300,bibatch Loss = 0.6753, Training Accuracy = 0.576
# Step 1400,bibatch Loss = 0.6833, Training Accuracy = 0.564
# Step 1500,bibatch Loss = 0.6707, Training Accuracy = 0.588
# Step 1600,bibatch Loss = 0.6667, Training Accuracy = 0.570
# Step 1700,bibatch Loss = 0.6750, Training Accuracy = 0.558
# Step 1800,bibatch Loss = 0.6630, Training Accuracy = 0.560
# Step 1900,bibatch Loss = 0.6672, Training Accuracy = 0.582
# Overall Training Accuracy: 0.55544734
# Testing Accuracy: 0.50252503
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_11
# Prediction for period 11 successfully shaved.
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 12 from 2018-12-31 06:29:06...
# -------------------------------------------------------------------------------------------------------
# INFO:tensorflow:Restoring parameters from C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_11
# Model restored from file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_11
# Step 0,bibatch Loss = 0.6769, Training Accuracy = 0.556
# Step 100,bibatch Loss = 0.6851, Training Accuracy = 0.548
# Step 200,bibatch Loss = 0.6826, Training Accuracy = 0.514
# Step 300,bibatch Loss = 0.6879, Training Accuracy = 0.532
# Step 400,bibatch Loss = 0.6802, Training Accuracy = 0.542
# Step 500,bibatch Loss = 0.6818, Training Accuracy = 0.582
# Step 600,bibatch Loss = 0.6821, Training Accuracy = 0.556
# Step 700,bibatch Loss = 0.6885, Training Accuracy = 0.524
# Step 800,bibatch Loss = 0.6782, Training Accuracy = 0.552
# Step 900,bibatch Loss = 0.6816, Training Accuracy = 0.522
# Step 1000,bibatch Loss = 0.6891, Training Accuracy = 0.548
# Step 1100,bibatch Loss = 0.6766, Training Accuracy = 0.596
# Step 1200,bibatch Loss = 0.6714, Training Accuracy = 0.574
# Step 1300,bibatch Loss = 0.6760, Training Accuracy = 0.536
# Step 1400,bibatch Loss = 0.6686, Training Accuracy = 0.560
# Step 1500,bibatch Loss = 0.6711, Training Accuracy = 0.546
# Step 1600,bibatch Loss = 0.6734, Training Accuracy = 0.546
# Step 1700,bibatch Loss = 0.6822, Training Accuracy = 0.502
# Step 1800,bibatch Loss = 0.6711, Training Accuracy = 0.584
# Step 1900,bibatch Loss = 0.6805, Training Accuracy = 0.566
# Overall Training Accuracy: 0.5525863
# Testing Accuracy: 0.49951407
# Model saved in file: C:\Users\Dian\OneDrive\Studying\Quantitative Finance\Deep Learning\Project\Logs\model_for_period_12
# Prediction for period 12 successfully shaved.
